# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Pipeline de Dados do Telegram I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Contexto;</li>
#   <li>Telegram;</li>
#   <li>Dados.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Telegram.

# %% [markdown]
# Replique as atividades da aula 2.

# %% [markdown]
# 1.1. Crie uma conta no **Telegram** caso não possua uma e faça o login na versão web da ferramenta através desse [link](https://web.telegram.org).

# %% [markdown]
# 1.2. Crie um *bot*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.3. Crie um grupo e adicione o *bot*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.4. Torne o *bot* administrador do grupo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.5. Desabilite a opção de adicionar o *bot* a novos grupos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.6. Envie diversos tipos de mensagens no grupo (text, imagem, arquivos, video, áudio, etc.) e as consuma utilizand a API de *bots* do **Telegram**.

# %% [markdown]
# > **Nota:** A documentação completa da API pode ser encontrada neste [link](https://core.telegram.org/bots/api)

# %%
# Solução do item 1.6.
from getpass import getpass

token = getpass()
# Out:
# ··········

# %%
import json

import requests

base_url = f'https://api.telegram.org/bot{token}'

# %%
response = requests.get(url=f'{base_url}/getMe')
print(f'{base_url}/getMe')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# https://api.telegram.org/bot7552765691:AAG7vjbiW8MeLyOekj-ADHl6_IWyPK-CioQ/getMe
# {
#   "ok": true,
#   "result": {
#     "id": 7552765691,
#     "is_bot": true,
#     "first_name": "Molotof_ebac_bot",
#     "username": "Molotof_ebac_bot",
#     "can_join_groups": true,
#     "can_read_all_group_messages": false,
#     "supports_inline_queries": false,
#     "can_connect_to_business": false,
#     "has_main_web_app": false
#   }
# }

# %%
response = requests.get(url=f'{base_url}/getUpdates')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": [
#     {
#       "update_id": 400036283,
#       "message": {
#         "message_id": 9,
#         "from": {
#           "id": 791325367,
#           "is_bot": false,
#           "first_name": "Bruno",
#           "last_name": "Zimmermann",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002830963420,
#           "title": "Bruno, Molotof_ebac_bot",
#           "type": "supergroup"
#         },
#         "date": 1749669487,
#         "text": "bom dia"
#       }
#     },
#     {
#       "update_id": 400036284,
#       "message": {
#         "message_id": 10,
#         "from": {
#           "id": 791325367,
#           "is_bot": false,
#           "first_name": "Bruno",
#           "last_name": "Zimmermann",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002830963420,
#           "title": "Bruno, Molotof_ebac_bot",
#           "type": "supergroup"
#         },
#         "date": 1749669499,
#         "text": "como vai com muta alegria"
#       }
#     },
#     {
#       "update_id": 400036285,
#       "message": {
#         "message_id": 11,
#         "from": {
#           "id": 791325367,
#           "is_bot": false,
#           "first_name": "Bruno",
#           "last_name": "Zimmermann",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002830963420,
#           "title": "Bruno, Molotof_ebac_bot",
#           "type": "supergroup"
#         },
#         "date": 1749669502,
#         "text": "?"
#       }
#     },
#     {
#       "update_id": 400036286,
#       "message": {
#         "message_id": 12,
#         "from": {
#           "id": 791325367,
#           "is_bot": false,
#           "first_name": "Bruno",
#           "last_name": "Zimmermann",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002830963420,
#           "title": "Bruno, Molotof_ebac_bot",
#           "type": "supergroup"
#         },
#         "date": 1749669558,
#         "video": {
#           "duration": 31,
#           "width": 720,
#           "height": 1280,
#           "mime_type": "video/mp4",
#           "thumbnail": {
#             "file_id": "AAMCAQADIQUABKi9EtwAAwxoSda1OrFp8XcmEvNlT3sy5G44fwAC0wQAAtx4UUZU-rqLztHh9AEAB20AAzYE",
#             "file_unique_id": "AQAD0wQAAtx4UUZy",
#             "file_size": 7313,
#             "width": 180,
#             "height": 320
#           },
#           "thumb": {
#             "file_id": "AAMCAQADIQUABKi9EtwAAwxoSda1OrFp8XcmEvNlT3sy5G44fwAC0wQAAtx4UUZU-rqLztHh9AEAB20AAzYE",
#             "file_unique_id": "AQAD0wQAAtx4UUZy",
#             "file_size": 7313,
#             "width": 180,
#             "height": 320
#           },
#           "file_id": "BAACAgEAAyEFAASovRLcAAMMaEnWtTqxafF3JhLzZU97MuRuOH8AAtMEAALceFFGVPq6i87R4fQ2BA",
#           "file_unique_id": "AgAD0wQAAtx4UUY",
#           "file_size": 2486581
#         }
#       }
#     }
#   ]
# }
