# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Controle de Versão II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Adicionar e salvar;</li>
#   <li>Visualizar e reverter;</li>
#   <li>Persistir e atualizar.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Setup

# %% [markdown]
# Para realizar os exercicios vamos configurar o `git` e trazer o projeto do GitHub para a a máquina virtual do Google Colab (ou na sua máquina local, as instruções são as mesmas). Para tanto, replique as atividades expostas na aula 1 deste módulo.

# %% [markdown]
# ### **1.1. Autenticação**

# %% [markdown]
# Nesta etapa, vamos configura o `git` com suas credenciais.

# %%
import os

username = "zizi155" # insira o seu nome de usuário do git
os.environ["GITHUB_USER"] = username

# !git config --global user.name "${GITHUB_USER}"

# %%
import os
from getpass import getpass

usermail = getpass()
os.environ["GITHUB_MAIL"] = usermail

# !git config --global user.email "${GITHUB_MAIL}"
# Out:
# ··········

# %%
import os
from getpass import getpass

usertoken = getpass()
os.environ["GITHUB_TOKEN"] = usertoken
# Out:
# ··········

# %% [markdown]
# ### **1.2. Projeto**

# %% [markdown]
# Nesta etapa, vamos trazer o projeto do GitHub para máquina local.

# %%
# !git clone https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/zizi155/da-ebac.git
# Out:
# Cloning into 'da-ebac'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 11 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), 4.75 KiB | 2.37 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd /content/da-ebac/
# Out:
# /content/da-ebac

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Preço da gasolina

# %% [markdown]
# O código abaixo gera um arquivo com o preço médio de venda da gasolina na cidade de São Paulo nos 10 primeiros dias de Julho de 2021.

# %%
# %%writefile gasolina.csv
# dia,venda
# 1,5.11
# 2,4.99
# 3,5.02
# 4,5.21
# 5,5.07
# 6,5.09
# 7,5.13
# 8,5.12
# 9,4.94
# 10,5.03
# Out:
# Writing gasolina.csv

# %% [markdown]
# ### **2.1. Desenvolvimento**

# %% [markdown]
# Gere uma gráfico de linha utilizando os dados do arquivo `gasolina.csv` com o dia no eixo `x`
#  e o seu preço no eixo `y` utilizando os pacotes Python de sua preferência, como o Pandas e o Seaborn. Salve o gráfico no arquivo `gasolina.png` e o seu código Python de geração no arquivo `gasolina.py`.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregar o arquivo CSV
file_path = 'gasolina.csv'
df = pd.read_csv(file_path)

# Criar o gráfico de linha
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='dia', y='venda', marker='o')

# Configurações do gráfico
plt.title('Preço da Gasolina por Dia')
plt.xlabel('Dia')
plt.ylabel('Preço (R$)')
plt.grid(True)

# Salvar o gráfico como gasolina.png
plt.savefig('gasolina.png')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# ### **2.2. Git**

# %% [markdown]
# Utilizando os comandos do `git`, adicione e "commite" os arquivos gerados (base, código Python e gráfico).

# %%
# !git commit -m "Adiciona arquivo CSV, código Python e gráfico gerado"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	gasolina.csv
# 	gasolina.png
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# ### **2.3. Github**

# %% [markdown]
# Utilizando os comandos do `git`, envie o seu commit para o GitHub.

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Arquivo README.md

# %% [markdown]
# O arquivo README.md é a porta de entrada do seu projeto, é ele que será renderizado quando o seu projeto for acessado, portanto, é importante que ele esteja bem escrito. Alguns exemplos:

# %% [markdown]
#  - [Pandas](https://github.com/pandas-dev/pandas);
#  - [Seaborn](https://github.com/mwaskom/seaborn);
#  - [Spark Cluster on Docker](https://github.com/cluster-apps-on-docker/spark-standalone-cluster-on-docker), esse projeto é meu! :)

# %% [markdown]
# ### **3.1. Desenvolvimento**

# %% [markdown]
# Altere o arquivo README.md com informações sobre seu repositório, inclua um título e uma breve descrição do repositório (no mínimo).

# %% [markdown]
# > **Dica**: o README.md pode ser configurado utilizando o padrão **markdown**, o mesmo que utilizamos nas células de texto aqui no Google Colab.

# %%
# %%writefile LEIA-ME.md
# criando um readme.md para subir no github
# Out:
# Writing LEIA-ME.md

# %% [markdown]
# ### **3.2. Git**

# %% [markdown]
# Utilizando os comandos do `git`, adicione e "commite" as alterações no arquivo `README.md`.

# %%
# Abrir (ou criar) o arquivo README.md e escrever o conteúdo
with open("README.md", "w") as file:
    file.write("# Nome do Repositório\n\n")
    file.write("Este repositório contém um projeto de análise de preços de gasolina. "
               "Inclui dados de preços diários, um script Python para gerar gráficos "
               "e o gráfico gerado em formato PNG.\n\n")
    file.write("## Conteúdo\n")
    file.write("- `gasolina.csv`: Arquivo CSV contendo os dados de preços de gasolina.\n")
    file.write("- `gasolina_code.py`: Script Python utilizado para gerar o gráfico.\n")
    file.write("- `gasolina.png`: Gráfico de linha mostrando a variação dos preços.\n")

# %%
# !git add README.md

# %%
# !git commit -m "Atualiza README.md com informações sobre o repositório"
# Out:
# [main b773436] Atualiza README.md com informações sobre o repositório
#  1 file changed, 8 insertions(+), 1 deletion(-)
#  rewrite README.md (100%)

# %% [markdown]
# ### **3.3. Github**

# %% [markdown]
# Utilizando os comandos do `git`, envie o seu commit para o GitHub.

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 540 bytes | 540.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/zizi155/da-ebac.git
#    4ce77db..b773436  main -> main

# %%
# !git add .
# !git commit -m "Resolvendo conflitos e integrando mudanças"
# Out:
# [main 7823c17] Resolvendo conflitos e integrando mudanças
#  3 files changed, 12 insertions(+)
#  create mode 100644 LEIA-ME.md
#  create mode 100644 gasolina.csv
#  create mode 100644 gasolina.png

# %%
# !git push origin main
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 36.27 KiB | 9.07 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/zizi155/da-ebac.git
#    b773436..7823c17  main -> main

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git commit -m "Resolvidos conflitos de mesclagem"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git pull --rebase origin main
# Out:
# From https://github.com/zizi155/da-ebac
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git add .
# !git rebase --continue
# Out:
# hint: Waiting for your editor to close the file... 7[>4;2m="/content/da-ebac/.git/COMMIT_EDITMSG" 15L, 575B▽  Pzz\[0%m           [>cAtualiza README.md com informações sobre o repositório# Please enter the commit message for your changes. Lines starting# with '#' will be ignored, and an empty message aborts the commit.
# #
# # interactive rebase in progress; onto a59d4aa
# # Last command done (1 command done):
# #    pick 405fe70 Atualiza README.md com informações sobre o repositório
# # Next command to do (1 remaining command):
# #    pick ba4f758 Resolvendo conflitos e integrando mudanças
# # You are currently rebasing branch 'main' on 'a59d4aa'.
# #
# # Changes to be committed:
# #       modified:   README.md
# #
# ...
