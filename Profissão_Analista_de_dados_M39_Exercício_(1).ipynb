# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem III
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>AWS EC2;</li>
#   <li>AWS SageMaker;</li>
#   <li>AWS Acesso Externo.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. AWS SageMaker

# %% [markdown]
# Replique as atividades do item 2.3 em sua conta.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](![image.png](data:image/png;base64,...))![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2\. AWS Acesso Externo

# %% [markdown]
# Replique as atividades do item 3.1 em sua conta.

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.38.25-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<1.39.0,>=1.38.25 (from boto3)
#   Downloading botocore-1.38.25-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.25->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.25->boto3) (2.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.25->boto3) (1.17.0)
# Downloading boto3-1.38.25-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 2.2 MB/s eta 0:00:00
# Downloading botocore-1.38.25-py3-none-any.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 66.1 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.38.25 botocore-1.38.25 jmespath-1.0.1 s3transfer-0.13.0

# %%
from getpass import getpass

aws_access_key_id = getpass()
# Out:
# ··········

# %%
from getpass import getpass

aws_secret_access_key = getpass()
# Out:
# ··········

# %%
import boto3
import pandas as pd

client = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)

# %%
BUCKET = 'modulo-40-ebac-segemaker'

client.download_file(BUCKET, 'cotacao.csv', 'cotacao_aws.csv')

# %%
df = pd.read_csv('cotacao_aws.csv')
df.head()
# Out:
#          date     usd     eur     gbp
# 0  2021-01-21  5.4582  6.1896  7.3980
# 1  2021-01-20  5.4191  6.1290  7.3673
# 2  2021-01-19  5.4383  6.1676  7.3994
# 3  2021-01-18  5.5666  6.3042  7.5672

# %%
client.upload_file(Filename='cotacao_aws.csv', Bucket=BUCKET, Key='cotacao_aws.csv')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/boto3/s3/transfer.py in upload_file(self, filename, bucket, key, callback, extra_args)
#     371         try:
# --> 372             future.result()
#     373         # If a client error was raised, add the backwards compatibility layer
#
# /usr/local/lib/python3.11/dist-packages/s3transfer/futures.py in result(self)
#     110             # out of this and propagate the exception.
# --> 111             return self._coordinator.result()
#     112         except KeyboardInterrupt as e:
#
# /usr/local/lib/python3.11/dist-packages/s3transfer/futures.py in result(self)
#     286         if self._exception:
# --> 287             raise self._exception
#     288         return self._result
#
# /usr/local/lib/python3.11/dist-packages/s3transfer/tasks.py in __call__(self, ctx)
#     141                 if not self._transfer_coordinator.done():
# --> 142                     return self._execute_main(kwargs)
#     143             except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/s3transfer/tasks.py in _execute_main(self, kwargs)
#     164
# --> 165         return_value = self._main(**kwargs)
#     166         # If the task is the final task, then set the TransferFuture's
#
# /usr/local/lib/python3.11/dist-packages/s3transfer/upload.py in _main(self, client, fileobj, bucket, key, extra_args)
#     795         with fileobj as body:
# --> 796             client.put_object(Bucket=bucket, Key=key, Body=body, **extra_args)
#     797
#
# /usr/local/lib/python3.11/dist-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     594             # The "self" in this scope is referring to the BaseClient.
# --> 595             return self._make_api_call(operation_name, kwargs)
#     596
#
# /usr/local/lib/python3.11/dist-packages/botocore/context.py in wrapper(*args, **kwargs)
#     122                     hook()
# --> 123                 return func(*args, **kwargs)
#     124
#
# /usr/local/lib/python3.11/dist-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#    1057             error_class = self.exceptions.from_code(error_code)
# -> 1058             raise error_class(parsed_response, operation_name)
#    1059         else:
#
# ClientError: An error occurred (AccessDenied) when calling the PutObject operation: User: arn:aws:iam::464967793684:user/modulo-40-ebac-segemaker is not authorized to perform: s3:PutObject on resource: "arn:aws:s3:::modulo-40-ebac-segemaker/cotacao_aws.csv" because no identity-based policy allows the s3:PutObject action
#
# During handling of the above exception, another exception occurred:
#
# S3UploadFailedError                       Traceback (most recent call last)
# <ipython-input-6-68d5fd1ce3b0> in <cell line: 0>()
# ----> 1 client.upload_file(Filename='cotacao_aws.csv', Bucket=BUCKET, Key='cotacao_aws.csv')
#
# /usr/local/lib/python3.11/dist-packages/botocore/context.py in wrapper(*args, **kwargs)
#     121                 if hook:
#     122                     hook()
# --> 123                 return func(*args, **kwargs)
#     124
#     125         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/boto3/s3/inject.py in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     173     """
#     174     with S3Transfer(self, Config) as transfer:
# --> 175         return transfer.upload_file(
#     176             filename=Filename,
#     177             bucket=Bucket,
#
# /usr/local/lib/python3.11/dist-packages/boto3/s3/transfer.py in upload_file(self, filename, bucket, key, callback, extra_args)
#     376         # client error.
#     377         except ClientError as e:
# --> 378             raise S3UploadFailedError(
#     379                 "Failed to upload {} to {}: {}".format(
#     380                     filename, '/'.join([bucket, key]), e
#
# S3UploadFailedError: Failed to upload cotacao_aws.csv to modulo-40-ebac-segemaker/cotacao_aws.csv: An error occurred (AccessDenied) when calling the PutObject operation: User: arn:aws:iam::464967793684:user/modulo-40-ebac-segemaker is not authorized to perform: s3:PutObject on resource: "arn:aws:s3:::modulo-40-ebac-segemaker/cotacao_aws.csv" because no identity-based policy allows the s3:PutObject action
